# %%
import pickle
import numpy as np

# %%
ohe_sex=pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked=pickle.load(open('models/ohe_embarked.pkl','rb'))
clf=pickle.load(open('models/clf.pkl','rb'))

# %%
# Assume user input 
#Pclass/Sex/Age/SibSp/Parch/Fare/Embarked

test_input= np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
# after getting the imput from the user we need to preprocess it like we did for training data
# But we don't do this because we are using non missing data for testing

test_input_sex=ohe_sex.transform(test_input[:,1].reshape(1,1))
test_input_embarked=ohe_embarked.transform(test_input[:,-1].reshape(1,1))
# Out:
# c:\Users\DSingh\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age=test_input[:,2].reshape(1,1)

# %%
test_input_transformed=np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed
# Out:
# array([[2, 0, 0, 10.5, 31.0, 0.0, 1.0, 0.0, 0.0, 1.0]], dtype=object)

# %%
clf.predict(test_input_transformed)
# Out:
# array([0])

# %%
## it brings so much complexity and need to obeserve the order to maintain the same order as we did in training
# so our next step is to use pipeline to avoid this complexity
# next file is day29_titanic_using_pipeline.ipynb
