# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup 
import numpy as np

# %%
requests.get('https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav').text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;46fdd417&#46;1757353083&#46;16773af3\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;46fdd417&#46;1757353083&#46;16773af3</P>\n</BODY>\n</HTML>\n'

# %%
import requests
url = 'https://www.ambitionbox.com/list-of-companies?sortBy=popular'
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)

# %%
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\DSingh\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument('--headless')
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(options=options)

driver.get('https://www.ambitionbox.com/list-of-companies?sortBy=popular')
html = driver.page_source
print(html[:1000])  # Inspect the content
driver.quit()
# Out:
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
