# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
X,y=make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df=pd.DataFrame(X,columns=['f1','f2','f3','f4','f5'])
df['target']=y
print(df.shape)
print(df.head())
# Out:
# (100, 6)
#          f1        f2        f3        f4        f5  target
# 0  1.330825  0.569286  1.942586  0.876656  0.052144       1
# 1  0.901290 -1.452438  1.243395  0.090841  0.963762       0
# 2 -1.625875  1.653642  0.286973  1.825091 -0.485142       1
# 3 -0.031111 -3.703670 -2.493254  0.630254  2.823337       0
# 4  1.677659 -1.367102 -0.121591  0.748030  0.519628       0

# %%
bag=BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf=RandomForestClassifier(max_features=2)
rf.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[0])
plt.show()
